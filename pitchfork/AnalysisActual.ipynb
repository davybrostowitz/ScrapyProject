# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv("pitchfork_reviews2.csv")
data
# Out:
#                                                    album  \
# 0                                          El Mal Querer
# 1                            You Won’t Get What You Want
# 2                       Wham! Bang! Pow! Let’s Rock Out!
# 3                         4AM Mulholland EP,After 4AM EP
# 4                                         Temporary etc.
# 5                                       Pop Ambient 2019
# 6                                              Moondance
# 7                                   Ghost Box (Expanded)
# 8                                                 Poison
# 9                              Lost Time Behind the Moon
# 10                                               Acrylic
# 11                               The Lillywhite Sessions
# 12                        Love in the Time of Lexapro EP
# 13                                    2 Minute Drills EP
# 14     From the Series of Songs “Altogether Unaccompa...
# ...

# %%
datasmall = data.loc[:,data.columns != 'content']
datasmall
# Out:
#                                                    album  \
# 0                                          El Mal Querer
# 1                            You Won’t Get What You Want
# 2                       Wham! Bang! Pow! Let’s Rock Out!
# 3                         4AM Mulholland EP,After 4AM EP
# 4                                         Temporary etc.
# 5                                       Pop Ambient 2019
# 6                                              Moondance
# 7                                   Ghost Box (Expanded)
# 8                                                 Poison
# 9                              Lost Time Behind the Moon
# 10                                               Acrylic
# 11                               The Lillywhite Sessions
# 12                        Love in the Time of Lexapro EP
# 13                                    2 Minute Drills EP
# 14     From the Series of Songs “Altogether Unaccompa...
# ...

# %%
datasmall.to_csv('smallpitchfork.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data1 = data.dropna(axis = 0, how='any')
data1
# Out:
#                                                    album  \
# 0                                          El Mal Querer
# 1                            You Won’t Get What You Want
# 2                       Wham! Bang! Pow! Let’s Rock Out!
# 3                         4AM Mulholland EP,After 4AM EP
# 4                                         Temporary etc.
# 6                                              Moondance
# 7                                   Ghost Box (Expanded)
# 8                                                 Poison
# 9                              Lost Time Behind the Moon
# 10                                               Acrylic
# 11                               The Lillywhite Sessions
# 12                        Love in the Time of Lexapro EP
# 13                                    2 Minute Drills EP
# 14     From the Series of Songs “Altogether Unaccompa...
# 15                                             Atardecer
# ...

# %%
data1 = data1.drop([3])

# %%
data1
# Out:
#                                                    album  \
# 0                                          El Mal Querer
# 1                            You Won’t Get What You Want
# 2                       Wham! Bang! Pow! Let’s Rock Out!
# 4                                         Temporary etc.
# 6                                              Moondance
# 7                                   Ghost Box (Expanded)
# 8                                                 Poison
# 9                              Lost Time Behind the Moon
# 10                                               Acrylic
# 11                               The Lillywhite Sessions
# 12                        Love in the Time of Lexapro EP
# 13                                    2 Minute Drills EP
# 14     From the Series of Songs “Altogether Unaccompa...
# 15                                             Atardecer
# 16                                             Up a Tree
# ...

# %%
data1.loc[184]
# Out:
# album                                                 Aviary
# artist                                          Julia Holter
# content    At the heart of ,’s pristine chamber pop there...
# date                                         November 2 2018
# genre                                           Experimental
# label                                                 Domino
# score                                                    8.2
# Name: 184, dtype: object

# %%
data2 = pd.to_numeric(data1.score)
data2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "8.5,7.9,8.7,7.6"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-eede69326987> in <module>()
# ----> 1 data2 = pd.to_numeric(data1.score)
#       2 data2
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     131             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     132             values = lib.maybe_convert_numeric(values, set(),
# --> 133                                                coerce_numeric=coerce_numeric)
#     134
#     135     except Exception:
#
# ...

# %%
data2 = pd.to_numeric(data1.score)
data2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "7.0,7.3,9.0,8.5"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-eede69326987> in <module>()
# ----> 1 data2 = pd.to_numeric(data1.score)
#       2 data2
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     131             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     132             values = lib.maybe_convert_numeric(values, set(),
# --> 133                                                coerce_numeric=coerce_numeric)
#     134
#     135     except Exception:
#
# ...

# %%
labelgroup = data.groupby('label')
labelgroup

# %%
labelgroup.mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-12-ff05349b6bbc> in <module>()
# ----> 1 labelgroup.mean()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1304         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1305         try:
# -> 1306             return self._cython_agg_general('mean', **kwargs)
#    1307         except GroupByError:
#    1308             raise
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    3970                             min_count=-1):
#    3971         new_items, new_blocks = self._cython_agg_blocks(
# -> 3972             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
#    3973         return self._wrap_agged_blocks(new_items, new_blocks)
# ...
